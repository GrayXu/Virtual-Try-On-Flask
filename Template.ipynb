# %%
from Model import Model
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import time
import cv2

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %matplotlib inline

# %%
model = Model("checkpoints/jpp.pb",
              "checkpoints/gmm.pth", 
              "checkpoints/tom.pth")
# Out:
# WARNING:tensorflow:From /mnt/zhoubaicun3/xuguanglei/vto-flask/JPPNet.py:19: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# initialization method [normal]
# initialization method [normal]

# %%
img = np.array(Image.open("../Virtual-Try-On/data/test/image/000066_0.jpg"))
plt.imshow(img)

# %%
c_img = np.array(Image.open("example/cloth.jpg"))
plt.imshow(c_img)

# %%
start = time.time()
result,trusts = model.predict(img, c_img, need_pre=False,check_dirty=True)
if result is not None:
    end = time.time()
    print("time:"+str(end-start))
    print("Confidence"+str(trusts))
    plt.imshow(result)
# Out:
# 2nd case false
# time:0.6399462223052979
# 置信度0.711753599345684

# %% [markdown]
# GPU: Tesla P40
# Each prediction costs 0.6s per image.
# Loading all models costs GPU memory about 7.16 GBs.
